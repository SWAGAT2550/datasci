# %%
import numpy as np
import cv2

# %%
img= cv2.imread('Downloads/faces.jpg')

# %%
img.shape
# Out:
# (628, 718, 3)

# %%
img[0]
# Out:
# array([[ 70,  74,  79],
#        [ 71,  75,  80],
#        [ 70,  75,  78],
#        ...,
#        [100, 109, 136],
#        [101, 110, 137],
#        [102, 111, 138]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
while True:
    cv2.imshow('results',img)
    if cv2.waitKey(2) == 27:
        break
cv2.destroyAllWindows()

# %%
haar_data = cv2.CascadeClassifier('Downloads/haarcascade_frontalface_default.xml')

# %%
haar_data.detectMultiScale(img)
# Out:
# array([[152,  84, 384, 384]], dtype=int32)

# %%
while True:
    face = haar_data.detectMultiScale(img)
    for x,y,w,h in face:
        cv2.rectangle(img,(x,y),(x+w , y+h),(255,0,255), 4)
    cv2.imshow('results',img)
    if cv2.waitKey(2) == 27:
        break
cv2.destroyAllWindows()

# %%
capture = cv2.VideoCapture(0)
data = []
while True:
    flag, img = capture.read()
    
    if flag:
        faces = haar_data.detectMultiScale(img)
    for x,y,w,h in face:
        
        cv2.rectangle(img,(x,y),(x+w , y+h), (255,0,255), 4)
        face = img[y:y+h, x:x+w, : ]
        face = cv2.resize(face, (50,50))
        print (len(data))
        if len(data) < 400:
            data.append(face)
    cv2.imshow('results',img)
    if cv2.waitKey(2) == 27 or len(data) >= 200:
        break

capture.release()
cv2.destroyAllWindows()
# Out:
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-68b4dcdc4112> in <module>
#       6     if flag:
#       7         faces = haar_data.detectMultiScale(img)
# ----> 8     for x,y,w,h in face:
#       9
#      10         cv2.rectangle(img,(x,y),(x+w , y+h), (255,0,255), 4)
#
# ValueError: too many values to unpack (expected 4)
